# %% [markdown]
# <a href="https://colab.research.google.com/github/TruongDuyLongPTIT/makeyourownneuralnetwork/blob/master/Test_my_model_p2p_01_4_99303_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.9.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
        elif split == 'val':
            self.path = self.processed_paths[1]
        elif split == 'test':
            self.path = self.processed_paths[2]

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
            self.num_graphs = self.data['num_graphs']
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            with h5py.File(self.path, 'r') as f:
                self.num_graphs = f.attrs['num_graphs']
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/P2P'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 8
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    class_weight = torch.Tensor([0.1, 4])
    class_weight = class_weight.cuda(device=0)
    criterion = torch.nn.CrossEntropyLoss(weight=class_weight)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-bafe8c0d-d58b-4e66-8954-8ffd652c6712.json
# ------------------------------
# ------------------------------
# Sat Oct 22 14:35:46 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 8
# epoch: 1, passed number of graphs: 96, train running loss: 0.08642 (passed time: 15s)
#           acc: 0.66785, fpr: 0.32738, fnr: 0.54801, rec: 0.45199, prc: 0.02961, f1: 0.05558, f1_macro: 0.42703
# epoch: 1, passed number of graphs: 192, train running loss: 0.08241 (passed time: 29s)
#           acc: 0.71702, fpr: 0.28640, fnr: 0.12674, rec: 0.87326, prc: 0.06255, f1: 0.11674, f1_macro: 0.47413
# epoch: 1, passed number of graphs: 288, train running loss: 0.07625 (passed time: 42s)
#           acc: 0.74105, fpr: 0.26408, fnr: 0.02371, rec: 0.97629, prc: 0.07463, f1: 0.13865, f1_macro: 0.49314
# epoch: 1, passed number of graphs: 384, train running loss: 0.06680 (passed time: 56s)
#           acc: 0.89482, fpr: 0.10666, fnr: 0.03760, rec: 0.96240, prc: 0.16553, f1: 0.28247, f1_macro: 0.61286
# epoch: 1, passed number of graphs: 480, train running loss: 0.05748 (passed time: 1m 9s)
#           acc: 0.94910, fpr: 0.05092, fnr: 0.05025, rec: 0.94975, prc: 0.29252, f1: 0.44728, f1_macro: 0.71030
# epoch: 1, passed number of graphs: 576, train running loss: 0.04991 (passed time: 1m 23s)
#           acc: 0.97295, fpr: 0.02726, fnr: 0.01765, rec: 0.98235, prc: 0.44210, f1: 0.60977, f1_macro: 0.79788
# epoch: 1, passed number of graphs: 672, train running loss: 0.04471 (passed time: 1m 37s)
#           acc: 0.96956, fpr: 0.03031, fnr: 0.03630, rec: 0.96370, prc: 0.41329, f1: 0.57849, f1_macro: 0.78135
# epoch: 1, passed number of graphs: 768, train running loss: 0.04012 (passed time: 1m 51s)
#           acc: 0.98948, fpr: 0.01068, fnr: 0.00316, rec: 0.99684, prc: 0.66979, f1: 0.80123, f1_macro: 0.89791
# Validation --- epoch: 1, loss: 0.12021
#           prc: 0.48999, fnr: 0.03803, f1_macro: 0.81805, acc: 0.97734, f1: 0.64782, fpr: 0.02233, rec: 0.96197
# Better model saved at ./saved_models/GIN_0: 0.6478185985194825.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.00823 (passed time: 2m 36s)
#           acc: 0.99171, fpr: 0.00838, fnr: 0.00419, rec: 0.99581, prc: 0.72415, f1: 0.83853, f1_macro: 0.91714
# epoch: 2, passed number of graphs: 192, train running loss: 0.00818 (passed time: 2m 50s)
#           acc: 0.98644, fpr: 0.01266, fnr: 0.05494, rec: 0.94506, prc: 0.62036, f1: 0.74904, f1_macro: 0.87103
# epoch: 2, passed number of graphs: 288, train running loss: 0.00766 (passed time: 3m 4s)
#           acc: 0.99113, fpr: 0.00906, fnr: 0.00057, rec: 0.99943, prc: 0.70652, f1: 0.82783, f1_macro: 0.91164
# epoch: 2, passed number of graphs: 384, train running loss: 0.00648 (passed time: 3m 18s)
#           acc: 0.99864, fpr: 0.00139, fnr: 0.00000, rec: 1.00000, prc: 0.94049, f1: 0.96933, f1_macro: 0.98432
# epoch: 2, passed number of graphs: 480, train running loss: 0.00564 (passed time: 3m 32s)
#           acc: 0.99759, fpr: 0.00134, fnr: 0.05110, rec: 0.94890, prc: 0.94031, f1: 0.94458, f1_macro: 0.97168
# epoch: 2, passed number of graphs: 576, train running loss: 0.00530 (passed time: 3m 46s)
#           acc: 0.99101, fpr: 0.00917, fnr: 0.00081, rec: 0.99919, prc: 0.70552, f1: 0.82706, f1_macro: 0.91122
# epoch: 2, passed number of graphs: 672, train running loss: 0.00533 (passed time: 4m 0s)
#           acc: 0.99433, fpr: 0.00514, fnr: 0.02992, rec: 0.97008, prc: 0.80709, f1: 0.88111, f1_macro: 0.93910
# epoch: 2, passed number of graphs: 768, train running loss: 0.00513 (passed time: 4m 14s)
#           acc: 0.99598, fpr: 0.00411, fnr: 0.00004, rec: 0.99996, prc: 0.84108, f1: 0.91367, f1_macro: 0.95580
# Validation --- epoch: 2, loss: 0.01178
#           prc: 0.98227, fnr: 0.01991, f1_macro: 0.98962, acc: 0.99917, f1: 0.97967, fpr: 0.00041, rec: 0.98009
# Better model saved at ./saved_models/GIN_1: 0.9796705282195163.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.00271 (passed time: 4m 50s)
#           acc: 0.99993, fpr: 0.00005, fnr: 0.00089, rec: 0.99911, prc: 0.99775, f1: 0.99843, f1_macro: 0.99920
# epoch: 3, passed number of graphs: 192, train running loss: 0.00291 (passed time: 5m 4s)
#           acc: 0.99515, fpr: 0.00461, fnr: 0.01590, rec: 0.98410, prc: 0.82366, f1: 0.89676, f1_macro: 0.94714
# epoch: 3, passed number of graphs: 288, train running loss: 0.00262 (passed time: 5m 18s)
#           acc: 0.99775, fpr: 0.00230, fnr: 0.00020, rec: 0.99980, prc: 0.90466, f1: 0.94985, f1_macro: 0.97435
# epoch: 3, passed number of graphs: 384, train running loss: 0.00237 (passed time: 5m 33s)
#           acc: 0.99922, fpr: 0.00077, fnr: 0.00125, rec: 0.99875, prc: 0.96628, f1: 0.98224, f1_macro: 0.99092
# epoch: 3, passed number of graphs: 480, train running loss: 0.00214 (passed time: 5m 47s)
#           acc: 0.99855, fpr: 0.00036, fnr: 0.05081, rec: 0.94919, prc: 0.98317, f1: 0.96588, f1_macro: 0.98257
# epoch: 3, passed number of graphs: 576, train running loss: 0.00205 (passed time: 6m 1s)
#           acc: 0.99966, fpr: 0.00035, fnr: 0.00016, rec: 0.99984, prc: 0.98438, f1: 0.99205, f1_macro: 0.99594
# epoch: 3, passed number of graphs: 672, train running loss: 0.00236 (passed time: 6m 15s)
#           acc: 0.99747, fpr: 0.00234, fnr: 0.01100, rec: 0.98900, prc: 0.90355, f1: 0.94434, f1_macro: 0.97153
# epoch: 3, passed number of graphs: 768, train running loss: 0.00261 (passed time: 6m 29s)
#           acc: 0.99767, fpr: 0.00237, fnr: 0.00028, rec: 0.99972, prc: 0.90149, f1: 0.94807, f1_macro: 0.97344
# Validation --- epoch: 3, loss: 0.09617
#           prc: -0.94792, fnr: 0.99999, f1_macro: nan, acc: 0.97848, f1: 0.00001, fpr: 0.00000, rec: 0.00001
# epoch: 4, passed number of graphs: 96, train running loss: 0.00461 (passed time: 7m 4s)
#           acc: 0.99544, fpr: 0.00465, fnr: 0.00016, rec: 0.99984, prc: 0.82608, f1: 0.90469, f1_macro: 0.95118
# epoch: 4, passed number of graphs: 192, train running loss: 0.00509 (passed time: 7m 19s)
#           acc: 0.99449, fpr: 0.00439, fnr: 0.05656, rec: 0.94344, prc: 0.82459, f1: 0.88002, f1_macro: 0.93860
# epoch: 4, passed number of graphs: 288, train running loss: 0.00471 (passed time: 7m 33s)
#           acc: 0.97607, fpr: 0.02445, fnr: 0.00000, rec: 1.00000, prc: 0.47148, f1: 0.64083, f1_macro: 0.81423
# epoch: 4, passed number of graphs: 384, train running loss: 0.00806 (passed time: 7m 47s)
#           acc: 0.88056, fpr: 0.12034, fnr: 0.07832, rec: 0.92168, prc: 0.14411, f1: 0.24925, f1_macro: 0.59219
# epoch: 4, passed number of graphs: 480, train running loss: 0.01199 (passed time: 8m 1s)
#           acc: 0.95970, fpr: 0.03986, fnr: 0.06024, rec: 0.93976, prc: 0.34326, f1: 0.50285, f1_macro: 0.74093
# epoch: 4, passed number of graphs: 576, train running loss: 0.01146 (passed time: 8m 15s)
#           acc: 0.98801, fpr: 0.01212, fnr: 0.00606, rec: 0.99394, prc: 0.64327, f1: 0.78105, f1_macro: 0.88744
# epoch: 4, passed number of graphs: 672, train running loss: 0.01110 (passed time: 8m 29s)
#           acc: 0.98850, fpr: 0.01110, fnr: 0.02948, rec: 0.97052, prc: 0.65959, f1: 0.78540, f1_macro: 0.88975
# epoch: 4, passed number of graphs: 768, train running loss: 0.01029 (passed time: 8m 43s)
#           acc: 0.98887, fpr: 0.01136, fnr: 0.00069, rec: 0.99931, prc: 0.65654, f1: 0.79245, f1_macro: 0.89337
# Validation --- epoch: 4, loss: 0.02509
#           prc: 0.82049, fnr: 0.02640, f1_macro: 0.94038, acc: 0.99413, f1: 0.88376, fpr: 0.00542, rec: 0.97360
# epoch: 5, passed number of graphs: 96, train running loss: 0.00498 (passed time: 9m 20s)
#           acc: 0.99457, fpr: 0.00553, fnr: 0.00076, rec: 0.99924, prc: 0.79960, f1: 0.88834, f1_macro: 0.94278
# epoch: 5, passed number of graphs: 192, train running loss: 0.00524 (passed time: 9m 33s)
#           acc: 0.98976, fpr: 0.00944, fnr: 0.04709, rec: 0.95291, prc: 0.68842, f1: 0.79936, f1_macro: 0.89705
# epoch: 5, passed number of graphs: 288, train running loss: 0.00461 (passed time: 9m 47s)
#           acc: 0.99372, fpr: 0.00640, fnr: 0.00061, rec: 0.99939, prc: 0.77304, f1: 0.87176, f1_macro: 0.93427
# epoch: 5, passed number of graphs: 384, train running loss: 0.00404 (passed time: 10m 1s)
#           acc: 0.99824, fpr: 0.00177, fnr: 0.00117, rec: 0.99883, prc: 0.92545, f1: 0.96074, f1_macro: 0.97992
# epoch: 5, passed number of graphs: 480, train running loss: 0.00365 (passed time: 10m 15s)
#           acc: 0.99652, fpr: 0.00242, fnr: 0.05118, rec: 0.94882, prc: 0.89691, f1: 0.92213, f1_macro: 0.96018
# epoch: 5, passed number of graphs: 576, train running loss: 0.00329 (passed time: 10m 29s)
#           acc: 0.99690, fpr: 0.00317, fnr: 0.00016, rec: 0.99984, prc: 0.87406, f1: 0.93273, f1_macro: 0.96557
# epoch: 5, passed number of graphs: 672, train running loss: 0.00335 (passed time: 10m 43s)
#           acc: 0.99610, fpr: 0.00396, fnr: 0.00108, rec: 0.99892, prc: 0.84814, f1: 0.91737, f1_macro: 0.95769
# epoch: 5, passed number of graphs: 768, train running loss: 0.00328 (passed time: 10m 57s)
#           acc: 0.99604, fpr: 0.00404, fnr: 0.00024, rec: 0.99976, prc: 0.84315, f1: 0.91480, f1_macro: 0.95639
# Validation --- epoch: 5, loss: 0.01819
#           prc: 0.86382, fnr: 0.00973, f1_macro: 0.95721, acc: 0.99568, f1: 0.91664, fpr: 0.00420, rec: 0.99027
# epoch: 6, passed number of graphs: 96, train running loss: 0.00136 (passed time: 11m 33s)
#           acc: 0.99857, fpr: 0.00145, fnr: 0.00036, rec: 0.99964, prc: 0.93822, f1: 0.96796, f1_macro: 0.98361
# epoch: 6, passed number of graphs: 192, train running loss: 0.00196 (passed time: 11m 46s)
#           acc: 0.99402, fpr: 0.00603, fnr: 0.00376, rec: 0.99624, prc: 0.78342, f1: 0.87710, f1_macro: 0.93702
# epoch: 6, passed number of graphs: 288, train running loss: 0.00175 (passed time: 12m 0s)
#           acc: 0.99734, fpr: 0.00271, fnr: 0.00016, rec: 0.99984, prc: 0.88936, f1: 0.94137, f1_macro: 0.97000
# epoch: 6, passed number of graphs: 384, train running loss: 0.00164 (passed time: 12m 14s)
#           acc: 0.99893, fpr: 0.00109, fnr: 0.00004, rec: 0.99996, prc: 0.95284, f1: 0.97583, f1_macro: 0.98764
# epoch: 6, passed number of graphs: 480, train running loss: 0.00152 (passed time: 12m 28s)
#           acc: 0.99865, fpr: 0.00025, fnr: 0.05110, rec: 0.94890, prc: 0.98824, f1: 0.96817, f1_macro: 0.98374
# epoch: 6, passed number of graphs: 576, train running loss: 0.00136 (passed time: 12m 42s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00016, rec: 0.99984, prc: 0.98540, f1: 0.99256, f1_macro: 0.99620
# epoch: 6, passed number of graphs: 672, train running loss: 0.00141 (passed time: 12m 56s)
#           acc: 0.99864, fpr: 0.00138, fnr: 0.00036, rec: 0.99964, prc: 0.94124, f1: 0.96956, f1_macro: 0.98443
# epoch: 6, passed number of graphs: 768, train running loss: 0.00139 (passed time: 13m 10s)
#           acc: 0.99771, fpr: 0.00234, fnr: 0.00008, rec: 0.99992, prc: 0.90273, f1: 0.94884, f1_macro: 0.97383
# Validation --- epoch: 6, loss: 0.00580
#           prc: 0.97923, fnr: 0.00911, f1_macro: 0.99169, acc: 0.99931, f1: 0.98373, fpr: 0.00051, rec: 0.99089
# Better model saved at ./saved_models/GIN_5: 0.98372760991922.pt.
# epoch: 7, passed number of graphs: 96, train running loss: 0.00067 (passed time: 13m 48s)
#           acc: 0.99895, fpr: 0.00106, fnr: 0.00048, rec: 0.99952, prc: 0.95404, f1: 0.97625, f1_macro: 0.98786
# epoch: 7, passed number of graphs: 192, train running loss: 0.00101 (passed time: 14m 1s)
#           acc: 0.99656, fpr: 0.00350, fnr: 0.00024, rec: 0.99976, prc: 0.86192, f1: 0.92574, f1_macro: 0.96199
# epoch: 7, passed number of graphs: 288, train running loss: 0.00094 (passed time: 14m 15s)
#           acc: 0.99825, fpr: 0.00179, fnr: 0.00008, rec: 0.99992, prc: 0.92425, f1: 0.96060, f1_macro: 0.97985
# epoch: 7, passed number of graphs: 384, train running loss: 0.00092 (passed time: 14m 29s)
#           acc: 0.99894, fpr: 0.00109, fnr: 0.00004, rec: 0.99996, prc: 0.95288, f1: 0.97585, f1_macro: 0.98765
# epoch: 7, passed number of graphs: 480, train running loss: 0.00083 (passed time: 14m 43s)
#           acc: 0.99916, fpr: 0.00050, fnr: 0.01576, rec: 0.98424, prc: 0.97741, f1: 0.98081, f1_macro: 0.99019
# epoch: 7, passed number of graphs: 576, train running loss: 0.00075 (passed time: 14m 57s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00012, rec: 0.99988, prc: 0.99163, f1: 0.99574, f1_macro: 0.99782
# epoch: 7, passed number of graphs: 672, train running loss: 0.00077 (passed time: 15m 10s)
#           acc: 0.99921, fpr: 0.00081, fnr: 0.00020, rec: 0.99980, prc: 0.96493, f1: 0.98205, f1_macro: 0.99082
# epoch: 7, passed number of graphs: 768, train running loss: 0.00076 (passed time: 15m 24s)
#           acc: 0.99916, fpr: 0.00086, fnr: 0.00004, rec: 0.99996, prc: 0.96185, f1: 0.98053, f1_macro: 0.99005
# Validation --- epoch: 7, loss: 0.14550
#           prc: 0.47998, fnr: 0.00445, f1_macro: 0.81138, acc: 0.97345, f1: 0.63656, fpr: 0.02703, rec: 0.99555
# epoch: 8, passed number of graphs: 96, train running loss: 0.00046 (passed time: 16m 2s)
#           acc: 0.99983, fpr: 0.00017, fnr: 0.00008, rec: 0.99992, prc: 0.99249, f1: 0.99619, f1_macro: 0.99805
# epoch: 8, passed number of graphs: 192, train running loss: 0.00066 (passed time: 16m 15s)
#           acc: 0.99869, fpr: 0.00134, fnr: 0.00024, rec: 0.99976, prc: 0.94249, f1: 0.97028, f1_macro: 0.98480
# epoch: 8, passed number of graphs: 288, train running loss: 0.00061 (passed time: 16m 29s)
#           acc: 0.99886, fpr: 0.00116, fnr: 0.00004, rec: 0.99996, prc: 0.94940, f1: 0.97402, f1_macro: 0.98672
# epoch: 8, passed number of graphs: 384, train running loss: 0.00075 (passed time: 16m 43s)
#           acc: 0.99904, fpr: 0.00093, fnr: 0.00267, rec: 0.99733, prc: 0.95947, f1: 0.97803, f1_macro: 0.98877
# epoch: 8, passed number of graphs: 480, train running loss: 0.00087 (passed time: 16m 57s)
#           acc: 0.99634, fpr: 0.00262, fnr: 0.05077, rec: 0.94923, prc: 0.88940, f1: 0.91834, f1_macro: 0.95823
# epoch: 8, passed number of graphs: 576, train running loss: 0.00088 (passed time: 17m 10s)
#           acc: 0.99665, fpr: 0.00343, fnr: 0.00008, rec: 0.99992, prc: 0.86518, f1: 0.92768, f1_macro: 0.96298
# epoch: 8, passed number of graphs: 672, train running loss: 0.00105 (passed time: 17m 24s)
#           acc: 0.99709, fpr: 0.00297, fnr: 0.00036, rec: 0.99964, prc: 0.88192, f1: 0.93710, f1_macro: 0.96780
# epoch: 8, passed number of graphs: 768, train running loss: 0.00107 (passed time: 17m 38s)
#           acc: 0.99798, fpr: 0.00207, fnr: 0.00012, rec: 0.99988, prc: 0.91320, f1: 0.95458, f1_macro: 0.97677
# Validation --- epoch: 8, loss: 0.04007
#           prc: 0.67982, fnr: 0.00650, f1_macro: 0.89203, acc: 0.98637, f1: 0.79112, fpr: 0.01379, rec: 0.99350
# epoch: 9, passed number of graphs: 96, train running loss: 0.00082 (passed time: 18m 15s)
#           acc: 0.99853, fpr: 0.00150, fnr: 0.00012, rec: 0.99988, prc: 0.93636, f1: 0.96708, f1_macro: 0.98316
# epoch: 9, passed number of graphs: 192, train running loss: 0.00102 (passed time: 18m 29s)
#           acc: 0.99614, fpr: 0.00391, fnr: 0.00154, rec: 0.99846, prc: 0.84814, f1: 0.91719, f1_macro: 0.95760
# epoch: 9, passed number of graphs: 288, train running loss: 0.00088 (passed time: 18m 43s)
#           acc: 0.99829, fpr: 0.00174, fnr: 0.00000, rec: 1.00000, prc: 0.92594, f1: 0.96154, f1_macro: 0.98034
# epoch: 9, passed number of graphs: 384, train running loss: 0.00090 (passed time: 18m 58s)
#           acc: 0.99899, fpr: 0.00104, fnr: 0.00000, rec: 1.00000, prc: 0.95501, f1: 0.97699, f1_macro: 0.98824
# epoch: 9, passed number of graphs: 480, train running loss: 0.00079 (passed time: 19m 12s)
#           acc: 0.99934, fpr: 0.00063, fnr: 0.00158, rec: 0.99842, prc: 0.97212, f1: 0.98509, f1_macro: 0.99238
# epoch: 9, passed number of graphs: 576, train running loss: 0.00072 (passed time: 19m 26s)
#           acc: 0.99983, fpr: 0.00017, fnr: 0.00004, rec: 0.99996, prc: 0.99211, f1: 0.99602, f1_macro: 0.99797
# epoch: 9, passed number of graphs: 672, train running loss: 0.00075 (passed time: 19m 40s)
#           acc: 0.99935, fpr: 0.00066, fnr: 0.00032, rec: 0.99968, prc: 0.97109, f1: 0.98518, f1_macro: 0.99242
# epoch: 9, passed number of graphs: 768, train running loss: 0.00073 (passed time: 19m 54s)
#           acc: 0.99925, fpr: 0.00076, fnr: 0.00008, rec: 0.99992, prc: 0.96610, f1: 0.98272, f1_macro: 0.99117
# Validation --- epoch: 9, loss: 0.00554
#           prc: 0.97373, fnr: 0.00693, f1_macro: 0.99084, acc: 0.99922, f1: 0.98209, fpr: 0.00065, rec: 0.99307
# epoch: 10, passed number of graphs: 96, train running loss: 0.00036 (passed time: 20m 33s)
#           acc: 0.99910, fpr: 0.00092, fnr: 0.00004, rec: 0.99996, prc: 0.96004, f1: 0.97959, f1_macro: 0.98957
# epoch: 10, passed number of graphs: 192, train running loss: 0.00056 (passed time: 20m 47s)
#           acc: 0.99905, fpr: 0.00096, fnr: 0.00069, rec: 0.99931, prc: 0.95815, f1: 0.97830, f1_macro: 0.98891
# epoch: 10, passed number of graphs: 288, train running loss: 0.00052 (passed time: 21m 1s)
#           acc: 0.99895, fpr: 0.00107, fnr: 0.00004, rec: 0.99996, prc: 0.95316, f1: 0.97600, f1_macro: 0.98773
# epoch: 10, passed number of graphs: 384, train running loss: 0.00056 (passed time: 21m 15s)
#           acc: 0.99900, fpr: 0.00102, fnr: 0.00000, rec: 1.00000, prc: 0.95560, f1: 0.97730, f1_macro: 0.98839
# epoch: 10, passed number of graphs: 480, train running loss: 0.00051 (passed time: 21m 29s)
#           acc: 0.99934, fpr: 0.00066, fnr: 0.00093, rec: 0.99907, prc: 0.97125, f1: 0.98496, f1_macro: 0.99231
# epoch: 10, passed number of graphs: 576, train running loss: 0.00047 (passed time: 21m 43s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00000, rec: 1.00000, prc: 0.99171, f1: 0.99584, f1_macro: 0.99787
# epoch: 10, passed number of graphs: 672, train running loss: 0.00050 (passed time: 21m 57s)
#           acc: 0.99957, fpr: 0.00044, fnr: 0.00036, rec: 0.99964, prc: 0.98070, f1: 0.99008, f1_macro: 0.99493
# epoch: 10, passed number of graphs: 768, train running loss: 0.00049 (passed time: 22m 11s)
#           acc: 0.99950, fpr: 0.00051, fnr: 0.00012, rec: 0.99988, prc: 0.97725, f1: 0.98844, f1_macro: 0.99409
# Validation --- epoch: 10, loss: 0.00440
#           prc: 0.98225, fnr: 0.00662, f1_macro: 0.99326, acc: 0.99944, f1: 0.98680, fpr: 0.00043, rec: 0.99338
# Better model saved at ./saved_models/GIN_9: 0.9867985820401052.pt.
# epoch: 11, passed number of graphs: 96, train running loss: 0.00029 (passed time: 22m 48s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00004, rec: 0.99996, prc: 0.99273, f1: 0.99633, f1_macro: 0.99812
# epoch: 11, passed number of graphs: 192, train running loss: 0.00045 (passed time: 23m 3s)
#           acc: 0.99946, fpr: 0.00054, fnr: 0.00045, rec: 0.99955, prc: 0.97575, f1: 0.98751, f1_macro: 0.99362
# epoch: 11, passed number of graphs: 288, train running loss: 0.00042 (passed time: 23m 17s)
#           acc: 0.99919, fpr: 0.00083, fnr: 0.00008, rec: 0.99992, prc: 0.96351, f1: 0.98138, f1_macro: 0.99048
# epoch: 11, passed number of graphs: 384, train running loss: 0.00046 (passed time: 23m 31s)
#           acc: 0.99902, fpr: 0.00101, fnr: 0.00000, rec: 1.00000, prc: 0.95623, f1: 0.97763, f1_macro: 0.98856
# epoch: 11, passed number of graphs: 480, train running loss: 0.00042 (passed time: 23m 45s)
#           acc: 0.99934, fpr: 0.00066, fnr: 0.00065, rec: 0.99935, prc: 0.97099, f1: 0.98497, f1_macro: 0.99231
# epoch: 11, passed number of graphs: 576, train running loss: 0.00039 (passed time: 23m 59s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00000, rec: 1.00000, prc: 0.99167, f1: 0.99582, f1_macro: 0.99786
# epoch: 11, passed number of graphs: 672, train running loss: 0.00042 (passed time: 24m 13s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00032, rec: 0.99968, prc: 0.98719, f1: 0.99340, f1_macro: 0.99662
# epoch: 11, passed number of graphs: 768, train running loss: 0.00042 (passed time: 24m 27s)
#           acc: 0.99957, fpr: 0.00044, fnr: 0.00012, rec: 0.99988, prc: 0.98008, f1: 0.98988, f1_macro: 0.99483
# Validation --- epoch: 11, loss: 0.00419
#           prc: 0.98185, fnr: 0.00501, f1_macro: 0.99360, acc: 0.99946, f1: 0.98747, fpr: 0.00044, rec: 0.99499
# Better model saved at ./saved_models/GIN_10: 0.9874703481368733.pt.
# epoch: 12, passed number of graphs: 96, train running loss: 0.00026 (passed time: 25m 4s)
#           acc: 0.99991, fpr: 0.00010, fnr: 0.00008, rec: 0.99992, prc: 0.99571, f1: 0.99781, f1_macro: 0.99888
# epoch: 12, passed number of graphs: 192, train running loss: 0.00039 (passed time: 25m 18s)
#           acc: 0.99956, fpr: 0.00044, fnr: 0.00032, rec: 0.99968, prc: 0.98009, f1: 0.98979, f1_macro: 0.99478
# epoch: 12, passed number of graphs: 288, train running loss: 0.00038 (passed time: 25m 33s)
#           acc: 0.99921, fpr: 0.00081, fnr: 0.00008, rec: 0.99992, prc: 0.96419, f1: 0.98173, f1_macro: 0.99066
# epoch: 12, passed number of graphs: 384, train running loss: 0.00041 (passed time: 25m 47s)
#           acc: 0.99959, fpr: 0.00041, fnr: 0.00004, rec: 0.99996, prc: 0.98154, f1: 0.99067, f1_macro: 0.99523
# epoch: 12, passed number of graphs: 480, train running loss: 0.00037 (passed time: 26m 1s)
#           acc: 0.99933, fpr: 0.00067, fnr: 0.00065, rec: 0.99935, prc: 0.97084, f1: 0.98489, f1_macro: 0.99227
# epoch: 12, passed number of graphs: 576, train running loss: 0.00035 (passed time: 26m 15s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00000, rec: 1.00000, prc: 0.99147, f1: 0.99572, f1_macro: 0.99781
# epoch: 12, passed number of graphs: 672, train running loss: 0.00037 (passed time: 26m 29s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00032, rec: 0.99968, prc: 0.99057, f1: 0.99510, f1_macro: 0.99750
# epoch: 12, passed number of graphs: 768, train running loss: 0.00037 (passed time: 26m 43s)
#           acc: 0.99962, fpr: 0.00038, fnr: 0.00008, rec: 0.99992, prc: 0.98270, f1: 0.99123, f1_macro: 0.99552
# Validation --- epoch: 12, loss: 0.00393
#           prc: 0.98280, fnr: 0.00448, f1_macro: 0.99399, acc: 0.99949, f1: 0.98824, fpr: 0.00042, rec: 0.99552
# Better model saved at ./saved_models/GIN_11: 0.9882411665814853.pt.
# epoch: 13, passed number of graphs: 96, train running loss: 0.00024 (passed time: 27m 19s)
#           acc: 0.99991, fpr: 0.00009, fnr: 0.00008, rec: 0.99992, prc: 0.99615, f1: 0.99803, f1_macro: 0.99899
# epoch: 13, passed number of graphs: 192, train running loss: 0.00036 (passed time: 27m 34s)
#           acc: 0.99959, fpr: 0.00041, fnr: 0.00032, rec: 0.99968, prc: 0.98157, f1: 0.99054, f1_macro: 0.99517
# epoch: 13, passed number of graphs: 288, train running loss: 0.00034 (passed time: 27m 48s)
#           acc: 0.99921, fpr: 0.00080, fnr: 0.00008, rec: 0.99992, prc: 0.96457, f1: 0.98193, f1_macro: 0.99076
# epoch: 13, passed number of graphs: 384, train running loss: 0.00037 (passed time: 28m 2s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00004, rec: 0.99996, prc: 0.98730, f1: 0.99359, f1_macro: 0.99673
# epoch: 13, passed number of graphs: 480, train running loss: 0.00034 (passed time: 28m 16s)
#           acc: 0.99933, fpr: 0.00067, fnr: 0.00065, rec: 0.99935, prc: 0.97053, f1: 0.98473, f1_macro: 0.99219
# epoch: 13, passed number of graphs: 576, train running loss: 0.00032 (passed time: 28m 30s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00000, rec: 1.00000, prc: 0.99171, f1: 0.99584, f1_macro: 0.99787
# epoch: 13, passed number of graphs: 672, train running loss: 0.00034 (passed time: 28m 44s)
#           acc: 0.99983, fpr: 0.00017, fnr: 0.00032, rec: 0.99968, prc: 0.99231, f1: 0.99598, f1_macro: 0.99794
# epoch: 13, passed number of graphs: 768, train running loss: 0.00034 (passed time: 28m 58s)
#           acc: 0.99970, fpr: 0.00031, fnr: 0.00008, rec: 0.99992, prc: 0.98595, f1: 0.99289, f1_macro: 0.99637
# Validation --- epoch: 13, loss: 0.00364
#           prc: 0.98405, fnr: 0.00444, f1_macro: 0.99434, acc: 0.99953, f1: 0.98892, fpr: 0.00039, rec: 0.99556
# Better model saved at ./saved_models/GIN_12: 0.9889208007357843.pt.
# epoch: 14, passed number of graphs: 96, train running loss: 0.00022 (passed time: 29m 35s)
#           acc: 0.99991, fpr: 0.00009, fnr: 0.00008, rec: 0.99992, prc: 0.99615, f1: 0.99803, f1_macro: 0.99899
# epoch: 14, passed number of graphs: 192, train running loss: 0.00033 (passed time: 29m 49s)
#           acc: 0.99958, fpr: 0.00042, fnr: 0.00032, rec: 0.99968, prc: 0.98118, f1: 0.99034, f1_macro: 0.99506
# epoch: 14, passed number of graphs: 288, train running loss: 0.00031 (passed time: 30m 3s)
#           acc: 0.99922, fpr: 0.00080, fnr: 0.00008, rec: 0.99992, prc: 0.96480, f1: 0.98204, f1_macro: 0.99082
# epoch: 14, passed number of graphs: 384, train running loss: 0.00034 (passed time: 30m 17s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00004, rec: 0.99996, prc: 0.98960, f1: 0.99475, f1_macro: 0.99732
# epoch: 14, passed number of graphs: 480, train running loss: 0.00031 (passed time: 30m 31s)
#           acc: 0.99932, fpr: 0.00068, fnr: 0.00057, rec: 0.99943, prc: 0.97011, f1: 0.98455, f1_macro: 0.99210
# epoch: 14, passed number of graphs: 576, train running loss: 0.00029 (passed time: 30m 45s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00000, rec: 1.00000, prc: 0.99183, f1: 0.99590, f1_macro: 0.99790
# epoch: 14, passed number of graphs: 672, train running loss: 0.00031 (passed time: 30m 59s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00036, rec: 0.99964, prc: 0.99278, f1: 0.99620, f1_macro: 0.99806
# epoch: 14, passed number of graphs: 768, train running loss: 0.00031 (passed time: 31m 13s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00008, rec: 0.99992, prc: 0.98867, f1: 0.99427, f1_macro: 0.99707
# Validation --- epoch: 14, loss: 0.00347
#           prc: 0.98419, fnr: 0.00442, f1_macro: 0.99438, acc: 0.99953, f1: 0.98901, fpr: 0.00038, rec: 0.99558
# Better model saved at ./saved_models/GIN_13: 0.9890071783671207.pt.
# epoch: 15, passed number of graphs: 96, train running loss: 0.00020 (passed time: 31m 51s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00012, rec: 0.99988, prc: 0.99623, f1: 0.99805, f1_macro: 0.99900
# epoch: 15, passed number of graphs: 192, train running loss: 0.00030 (passed time: 32m 5s)
#           acc: 0.99957, fpr: 0.00043, fnr: 0.00032, rec: 0.99968, prc: 0.98060, f1: 0.99004, f1_macro: 0.99491
# epoch: 15, passed number of graphs: 288, train running loss: 0.00029 (passed time: 32m 19s)
#           acc: 0.99922, fpr: 0.00079, fnr: 0.00008, rec: 0.99992, prc: 0.96499, f1: 0.98214, f1_macro: 0.99087
# epoch: 15, passed number of graphs: 384, train running loss: 0.00031 (passed time: 32m 33s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00004, rec: 0.99996, prc: 0.99059, f1: 0.99525, f1_macro: 0.99757
# epoch: 15, passed number of graphs: 480, train running loss: 0.00029 (passed time: 32m 47s)
#           acc: 0.99931, fpr: 0.00070, fnr: 0.00057, rec: 0.99943, prc: 0.96958, f1: 0.98428, f1_macro: 0.99196
# epoch: 15, passed number of graphs: 576, train running loss: 0.00027 (passed time: 33m 1s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00000, rec: 1.00000, prc: 0.99175, f1: 0.99586, f1_macro: 0.99788
# epoch: 15, passed number of graphs: 672, train running loss: 0.00029 (passed time: 33m 15s)
#           acc: 0.99983, fpr: 0.00017, fnr: 0.00032, rec: 0.99968, prc: 0.99258, f1: 0.99612, f1_macro: 0.99802
# epoch: 15, passed number of graphs: 768, train running loss: 0.00029 (passed time: 33m 29s)
#           acc: 0.99980, fpr: 0.00020, fnr: 0.00008, rec: 0.99992, prc: 0.99097, f1: 0.99543, f1_macro: 0.99766
# Validation --- epoch: 15, loss: 0.00336
#           prc: 0.98401, fnr: 0.00440, f1_macro: 0.99435, acc: 0.99953, f1: 0.98893, fpr: 0.00038, rec: 0.99560
# epoch: 16, passed number of graphs: 96, train running loss: 0.00019 (passed time: 34m 6s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00012, rec: 0.99988, prc: 0.99647, f1: 0.99817, f1_macro: 0.99907
# epoch: 16, passed number of graphs: 192, train running loss: 0.00028 (passed time: 34m 21s)
#           acc: 0.99953, fpr: 0.00048, fnr: 0.00016, rec: 0.99984, prc: 0.97870, f1: 0.98915, f1_macro: 0.99446
# epoch: 16, passed number of graphs: 288, train running loss: 0.00027 (passed time: 34m 35s)
#           acc: 0.99922, fpr: 0.00079, fnr: 0.00004, rec: 0.99996, prc: 0.96499, f1: 0.98216, f1_macro: 0.99088
# epoch: 16, passed number of graphs: 384, train running loss: 0.00029 (passed time: 34m 49s)
#           acc: 0.99980, fpr: 0.00020, fnr: 0.00000, rec: 1.00000, prc: 0.99087, f1: 0.99541, f1_macro: 0.99766
# epoch: 16, passed number of graphs: 480, train running loss: 0.00027 (passed time: 35m 3s)
#           acc: 0.99932, fpr: 0.00068, fnr: 0.00057, rec: 0.99943, prc: 0.97004, f1: 0.98452, f1_macro: 0.99208
# epoch: 16, passed number of graphs: 576, train running loss: 0.00026 (passed time: 35m 17s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00000, rec: 1.00000, prc: 0.99171, f1: 0.99584, f1_macro: 0.99787
# epoch: 16, passed number of graphs: 672, train running loss: 0.00027 (passed time: 35m 31s)
#           acc: 0.99983, fpr: 0.00017, fnr: 0.00024, rec: 0.99976, prc: 0.99235, f1: 0.99604, f1_macro: 0.99798
# epoch: 16, passed number of graphs: 768, train running loss: 0.00027 (passed time: 35m 45s)
#           acc: 0.99983, fpr: 0.00017, fnr: 0.00012, rec: 0.99988, prc: 0.99241, f1: 0.99613, f1_macro: 0.99802
# Validation --- epoch: 16, loss: 0.00346
#           prc: 0.98226, fnr: 0.00437, f1_macro: 0.99389, acc: 0.99949, f1: 0.98804, fpr: 0.00043, rec: 0.99563
# epoch: 17, passed number of graphs: 96, train running loss: 0.00018 (passed time: 36m 22s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00012, rec: 0.99988, prc: 0.99675, f1: 0.99831, f1_macro: 0.99914
# epoch: 17, passed number of graphs: 192, train running loss: 0.00026 (passed time: 36m 36s)
#           acc: 0.99951, fpr: 0.00050, fnr: 0.00012, rec: 0.99988, prc: 0.97769, f1: 0.98866, f1_macro: 0.99420
# epoch: 17, passed number of graphs: 288, train running loss: 0.00026 (passed time: 36m 50s)
#           acc: 0.99924, fpr: 0.00078, fnr: 0.00008, rec: 0.99992, prc: 0.96552, f1: 0.98242, f1_macro: 0.99101
# epoch: 17, passed number of graphs: 384, train running loss: 0.00027 (passed time: 37m 4s)
#           acc: 0.99980, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99067, f1: 0.99531, f1_macro: 0.99760
# epoch: 17, passed number of graphs: 480, train running loss: 0.00026 (passed time: 37m 18s)
#           acc: 0.99929, fpr: 0.00072, fnr: 0.00053, rec: 0.99947, prc: 0.96859, f1: 0.98379, f1_macro: 0.99171
# epoch: 17, passed number of graphs: 576, train running loss: 0.00024 (passed time: 37m 32s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00000, rec: 1.00000, prc: 0.99171, f1: 0.99584, f1_macro: 0.99787
# epoch: 17, passed number of graphs: 672, train running loss: 0.00026 (passed time: 37m 46s)
#           acc: 0.99983, fpr: 0.00017, fnr: 0.00020, rec: 0.99980, prc: 0.99223, f1: 0.99600, f1_macro: 0.99796
# epoch: 17, passed number of graphs: 768, train running loss: 0.00026 (passed time: 38m 1s)
#           acc: 0.99987, fpr: 0.00013, fnr: 0.00008, rec: 0.99992, prc: 0.99412, f1: 0.99701, f1_macro: 0.99847
# Validation --- epoch: 17, loss: 0.00315
#           prc: 0.98488, fnr: 0.00438, f1_macro: 0.99461, acc: 0.99955, f1: 0.98944, fpr: 0.00036, rec: 0.99562
# Better model saved at ./saved_models/GIN_16: 0.9894398954062412.pt.
# epoch: 18, passed number of graphs: 96, train running loss: 0.00018 (passed time: 38m 37s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00012, rec: 0.99988, prc: 0.99691, f1: 0.99839, f1_macro: 0.99918
# epoch: 18, passed number of graphs: 192, train running loss: 0.00025 (passed time: 38m 51s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00008, rec: 0.99992, prc: 0.97665, f1: 0.98815, f1_macro: 0.99394
# epoch: 18, passed number of graphs: 288, train running loss: 0.00024 (passed time: 39m 5s)
#           acc: 0.99924, fpr: 0.00077, fnr: 0.00008, rec: 0.99992, prc: 0.96582, f1: 0.98258, f1_macro: 0.99109
# epoch: 18, passed number of graphs: 384, train running loss: 0.00026 (passed time: 39m 19s)
#           acc: 0.99980, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99075, f1: 0.99535, f1_macro: 0.99762
# epoch: 18, passed number of graphs: 480, train running loss: 0.00024 (passed time: 39m 33s)
#           acc: 0.99928, fpr: 0.00072, fnr: 0.00053, rec: 0.99947, prc: 0.96855, f1: 0.98377, f1_macro: 0.99170
# epoch: 18, passed number of graphs: 576, train running loss: 0.00023 (passed time: 39m 47s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00000, rec: 1.00000, prc: 0.99171, f1: 0.99584, f1_macro: 0.99787
# epoch: 18, passed number of graphs: 672, train running loss: 0.00024 (passed time: 40m 1s)
#           acc: 0.99983, fpr: 0.00017, fnr: 0.00020, rec: 0.99980, prc: 0.99235, f1: 0.99606, f1_macro: 0.99799
# epoch: 18, passed number of graphs: 768, train running loss: 0.00025 (passed time: 40m 15s)
#           acc: 0.99990, fpr: 0.00010, fnr: 0.00008, rec: 0.99992, prc: 0.99525, f1: 0.99758, f1_macro: 0.99876
# Validation --- epoch: 18, loss: 0.00301
#           prc: 0.98765, fnr: 0.00437, f1_macro: 0.99539, acc: 0.99963, f1: 0.99098, fpr: 0.00028, rec: 0.99563
# Better model saved at ./saved_models/GIN_17: 0.9909790318158541.pt.
# epoch: 19, passed number of graphs: 96, train running loss: 0.00017 (passed time: 40m 52s)
#           acc: 0.99993, fpr: 0.00006, fnr: 0.00012, rec: 0.99988, prc: 0.99707, f1: 0.99847, f1_macro: 0.99922
# epoch: 19, passed number of graphs: 192, train running loss: 0.00024 (passed time: 41m 6s)
#           acc: 0.99946, fpr: 0.00055, fnr: 0.00008, rec: 0.99992, prc: 0.97553, f1: 0.98757, f1_macro: 0.99365
# epoch: 19, passed number of graphs: 288, train running loss: 0.00023 (passed time: 41m 21s)
#           acc: 0.99927, fpr: 0.00075, fnr: 0.00008, rec: 0.99992, prc: 0.96685, f1: 0.98311, f1_macro: 0.99137
# epoch: 19, passed number of graphs: 384, train running loss: 0.00025 (passed time: 41m 35s)
#           acc: 0.99980, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99075, f1: 0.99535, f1_macro: 0.99762
# epoch: 19, passed number of graphs: 480, train running loss: 0.00023 (passed time: 41m 49s)
#           acc: 0.99932, fpr: 0.00068, fnr: 0.00053, rec: 0.99947, prc: 0.97019, f1: 0.98461, f1_macro: 0.99213
# epoch: 19, passed number of graphs: 576, train running loss: 0.00022 (passed time: 42m 3s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00000, rec: 1.00000, prc: 0.99163, f1: 0.99580, f1_macro: 0.99785
# epoch: 19, passed number of graphs: 672, train running loss: 0.00023 (passed time: 42m 17s)
#           acc: 0.99983, fpr: 0.00017, fnr: 0.00020, rec: 0.99980, prc: 0.99258, f1: 0.99618, f1_macro: 0.99805
# epoch: 19, passed number of graphs: 768, train running loss: 0.00024 (passed time: 42m 31s)
#           acc: 0.99990, fpr: 0.00010, fnr: 0.00008, rec: 0.99992, prc: 0.99521, f1: 0.99756, f1_macro: 0.99875
# Validation --- epoch: 19, loss: 0.00379
#           prc: 0.97976, fnr: 0.00432, f1_macro: 0.99332, acc: 0.99945, f1: 0.98693, fpr: 0.00047, rec: 0.99568
# epoch: 20, passed number of graphs: 96, train running loss: 0.00017 (passed time: 43m 9s)
#           acc: 0.99994, fpr: 0.00006, fnr: 0.00012, rec: 0.99988, prc: 0.99715, f1: 0.99851, f1_macro: 0.99924
# epoch: 20, passed number of graphs: 192, train running loss: 0.00023 (passed time: 43m 24s)
#           acc: 0.99945, fpr: 0.00056, fnr: 0.00008, rec: 0.99992, prc: 0.97507, f1: 0.98734, f1_macro: 0.99353
# epoch: 20, passed number of graphs: 288, train running loss: 0.00022 (passed time: 43m 38s)
#           acc: 0.99928, fpr: 0.00074, fnr: 0.00008, rec: 0.99992, prc: 0.96727, f1: 0.98332, f1_macro: 0.99148
# epoch: 20, passed number of graphs: 384, train running loss: 0.00024 (passed time: 43m 52s)
#           acc: 0.99979, fpr: 0.00022, fnr: 0.00000, rec: 1.00000, prc: 0.99031, f1: 0.99513, f1_macro: 0.99751
# epoch: 20, passed number of graphs: 480, train running loss: 0.00022 (passed time: 44m 6s)
#           acc: 0.99932, fpr: 0.00068, fnr: 0.00053, rec: 0.99947, prc: 0.97012, f1: 0.98457, f1_macro: 0.99211
# epoch: 20, passed number of graphs: 576, train running loss: 0.00021 (passed time: 44m 20s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00000, rec: 1.00000, prc: 0.99135, f1: 0.99566, f1_macro: 0.99778
# epoch: 20, passed number of graphs: 672, train running loss: 0.00022 (passed time: 44m 34s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00020, rec: 0.99980, prc: 0.99274, f1: 0.99626, f1_macro: 0.99809
# epoch: 20, passed number of graphs: 768, train running loss: 0.00023 (passed time: 44m 48s)
#           acc: 0.99990, fpr: 0.00010, fnr: 0.00008, rec: 0.99992, prc: 0.99537, f1: 0.99764, f1_macro: 0.99879
# Validation --- epoch: 20, loss: 0.00339
#           prc: 0.98284, fnr: 0.00431, f1_macro: 0.99414, acc: 0.99952, f1: 0.98853, fpr: 0.00040, rec: 0.99569
# epoch: 21, passed number of graphs: 96, train running loss: 0.00016 (passed time: 45m 24s)
#           acc: 0.99991, fpr: 0.00009, fnr: 0.00008, rec: 0.99992, prc: 0.99599, f1: 0.99795, f1_macro: 0.99895
# epoch: 21, passed number of graphs: 192, train running loss: 0.00022 (passed time: 45m 39s)
#           acc: 0.99957, fpr: 0.00043, fnr: 0.00016, rec: 0.99984, prc: 0.98056, f1: 0.99010, f1_macro: 0.99494
# epoch: 21, passed number of graphs: 288, train running loss: 0.00021 (passed time: 45m 53s)
#           acc: 0.99955, fpr: 0.00046, fnr: 0.00004, rec: 0.99996, prc: 0.97926, f1: 0.98950, f1_macro: 0.99463
# epoch: 21, passed number of graphs: 384, train running loss: 0.00022 (passed time: 46m 7s)
#           acc: 0.99980, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99067, f1: 0.99531, f1_macro: 0.99760
# epoch: 21, passed number of graphs: 480, train running loss: 0.00021 (passed time: 46m 21s)
#           acc: 0.99923, fpr: 0.00078, fnr: 0.00028, rec: 0.99972, prc: 0.96612, f1: 0.98263, f1_macro: 0.99112
# epoch: 21, passed number of graphs: 576, train running loss: 0.00020 (passed time: 46m 35s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00004, rec: 0.99996, prc: 0.99259, f1: 0.99626, f1_macro: 0.99809
# epoch: 21, passed number of graphs: 672, train running loss: 0.00020 (passed time: 46m 49s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00012, rec: 0.99988, prc: 0.99262, f1: 0.99624, f1_macro: 0.99808
# epoch: 21, passed number of graphs: 768, train running loss: 0.00021 (passed time: 47m 3s)
#           acc: 0.99991, fpr: 0.00009, fnr: 0.00008, rec: 0.99992, prc: 0.99597, f1: 0.99794, f1_macro: 0.99895
# Validation --- epoch: 21, loss: 0.00261
#           prc: 0.99016, fnr: 0.00437, f1_macro: 0.99605, acc: 0.99969, f1: 0.99226, fpr: 0.00022, rec: 0.99563
# Better model saved at ./saved_models/GIN_20: 0.9922618875931959.pt.
# epoch: 22, passed number of graphs: 96, train running loss: 0.00016 (passed time: 47m 40s)
#           acc: 0.99991, fpr: 0.00009, fnr: 0.00008, rec: 0.99992, prc: 0.99611, f1: 0.99801, f1_macro: 0.99898
# epoch: 22, passed number of graphs: 192, train running loss: 0.00021 (passed time: 47m 55s)
#           acc: 0.99956, fpr: 0.00045, fnr: 0.00016, rec: 0.99984, prc: 0.98002, f1: 0.98983, f1_macro: 0.99480
# epoch: 22, passed number of graphs: 288, train running loss: 0.00021 (passed time: 48m 9s)
#           acc: 0.99958, fpr: 0.00043, fnr: 0.00004, rec: 0.99996, prc: 0.98075, f1: 0.99026, f1_macro: 0.99502
# epoch: 22, passed number of graphs: 384, train running loss: 0.00021 (passed time: 48m 23s)
#           acc: 0.99980, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99071, f1: 0.99533, f1_macro: 0.99761
# epoch: 22, passed number of graphs: 480, train running loss: 0.00020 (passed time: 48m 37s)
#           acc: 0.99923, fpr: 0.00078, fnr: 0.00028, rec: 0.99972, prc: 0.96612, f1: 0.98263, f1_macro: 0.99112
# epoch: 22, passed number of graphs: 576, train running loss: 0.00019 (passed time: 48m 51s)
#           acc: 0.99984, fpr: 0.00017, fnr: 0.00004, rec: 0.99996, prc: 0.99255, f1: 0.99624, f1_macro: 0.99808
# epoch: 22, passed number of graphs: 672, train running loss: 0.00020 (passed time: 49m 5s)
#           acc: 0.99984, fpr: 0.00017, fnr: 0.00012, rec: 0.99988, prc: 0.99259, f1: 0.99622, f1_macro: 0.99807
# epoch: 22, passed number of graphs: 768, train running loss: 0.00020 (passed time: 49m 19s)
#           acc: 0.99991, fpr: 0.00009, fnr: 0.00008, rec: 0.99992, prc: 0.99605, f1: 0.99798, f1_macro: 0.99897
# Validation --- epoch: 22, loss: 0.00261
#           prc: 0.98997, fnr: 0.00435, f1_macro: 0.99600, acc: 0.99968, f1: 0.99217, fpr: 0.00023, rec: 0.99565
# epoch: 23, passed number of graphs: 96, train running loss: 0.00016 (passed time: 49m 56s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99631, f1: 0.99811, f1_macro: 0.99903
# epoch: 23, passed number of graphs: 192, train running loss: 0.00021 (passed time: 50m 10s)
#           acc: 0.99956, fpr: 0.00045, fnr: 0.00016, rec: 0.99984, prc: 0.97994, f1: 0.98979, f1_macro: 0.99478
# epoch: 23, passed number of graphs: 288, train running loss: 0.00020 (passed time: 50m 25s)
#           acc: 0.99960, fpr: 0.00041, fnr: 0.00000, rec: 1.00000, prc: 0.98153, f1: 0.99068, f1_macro: 0.99524
# epoch: 23, passed number of graphs: 384, train running loss: 0.00021 (passed time: 50m 39s)
#           acc: 0.99980, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99071, f1: 0.99533, f1_macro: 0.99761
# epoch: 23, passed number of graphs: 480, train running loss: 0.00020 (passed time: 50m 53s)
#           acc: 0.99924, fpr: 0.00077, fnr: 0.00028, rec: 0.99972, prc: 0.96635, f1: 0.98275, f1_macro: 0.99118
# epoch: 23, passed number of graphs: 576, train running loss: 0.00019 (passed time: 51m 7s)
#           acc: 0.99984, fpr: 0.00017, fnr: 0.00004, rec: 0.99996, prc: 0.99247, f1: 0.99620, f1_macro: 0.99806
# epoch: 23, passed number of graphs: 672, train running loss: 0.00020 (passed time: 51m 21s)
#           acc: 0.99983, fpr: 0.00017, fnr: 0.00012, rec: 0.99988, prc: 0.99255, f1: 0.99620, f1_macro: 0.99806
# epoch: 23, passed number of graphs: 768, train running loss: 0.00020 (passed time: 51m 35s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99613, f1: 0.99802, f1_macro: 0.99899
# Validation --- epoch: 23, loss: 0.00261
#           prc: 0.98983, fnr: 0.00435, f1_macro: 0.99597, acc: 0.99968, f1: 0.99210, fpr: 0.00023, rec: 0.99565
# epoch: 24, passed number of graphs: 96, train running loss: 0.00015 (passed time: 52m 11s)
#           acc: 0.99991, fpr: 0.00009, fnr: 0.00008, rec: 0.99992, prc: 0.99583, f1: 0.99787, f1_macro: 0.99891
# epoch: 24, passed number of graphs: 192, train running loss: 0.00020 (passed time: 52m 26s)
#           acc: 0.99956, fpr: 0.00045, fnr: 0.00016, rec: 0.99984, prc: 0.98002, f1: 0.98983, f1_macro: 0.99480
# epoch: 24, passed number of graphs: 288, train running loss: 0.00020 (passed time: 52m 40s)
#           acc: 0.99966, fpr: 0.00035, fnr: 0.00004, rec: 0.99996, prc: 0.98414, f1: 0.99198, f1_macro: 0.99590
# epoch: 24, passed number of graphs: 384, train running loss: 0.00020 (passed time: 52m 54s)
#           acc: 0.99979, fpr: 0.00022, fnr: 0.00000, rec: 1.00000, prc: 0.99023, f1: 0.99509, f1_macro: 0.99749
# epoch: 24, passed number of graphs: 480, train running loss: 0.00019 (passed time: 53m 8s)
#           acc: 0.99921, fpr: 0.00080, fnr: 0.00024, rec: 0.99976, prc: 0.96499, f1: 0.98206, f1_macro: 0.99083
# epoch: 24, passed number of graphs: 576, train running loss: 0.00019 (passed time: 53m 22s)
#           acc: 0.99984, fpr: 0.00017, fnr: 0.00008, rec: 0.99992, prc: 0.99255, f1: 0.99622, f1_macro: 0.99807
# epoch: 24, passed number of graphs: 672, train running loss: 0.00019 (passed time: 53m 36s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00020, rec: 0.99980, prc: 0.99310, f1: 0.99644, f1_macro: 0.99818
# epoch: 24, passed number of graphs: 768, train running loss: 0.00020 (passed time: 53m 50s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00012, rec: 0.99988, prc: 0.99673, f1: 0.99830, f1_macro: 0.99913
# Validation --- epoch: 24, loss: 0.00238
#           prc: 0.99179, fnr: 0.00440, f1_macro: 0.99646, acc: 0.99972, f1: 0.99307, fpr: 0.00019, rec: 0.99560
# Better model saved at ./saved_models/GIN_23: 0.9930722964290255.pt.
# epoch: 25, passed number of graphs: 96, train running loss: 0.00015 (passed time: 54m 27s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99643, f1: 0.99817, f1_macro: 0.99907
# epoch: 25, passed number of graphs: 192, train running loss: 0.00020 (passed time: 54m 41s)
#           acc: 0.99957, fpr: 0.00044, fnr: 0.00016, rec: 0.99984, prc: 0.98036, f1: 0.99001, f1_macro: 0.99489
# epoch: 25, passed number of graphs: 288, train running loss: 0.00020 (passed time: 54m 55s)
# ...
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00008, rec: 0.99992, prc: 0.98635, f1: 0.99309, f1_macro: 0.99647
# epoch: 42, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 33m 41s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99035, f1: 0.99515, f1_macro: 0.99752
# epoch: 42, passed number of graphs: 480, train running loss: 0.00019 (passed time: 1h 33m 55s)
#           acc: 0.99920, fpr: 0.00081, fnr: 0.00024, rec: 0.99976, prc: 0.96465, f1: 0.98189, f1_macro: 0.99074
# epoch: 42, passed number of graphs: 576, train running loss: 0.00018 (passed time: 1h 34m 9s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00004, rec: 0.99996, prc: 0.99183, f1: 0.99588, f1_macro: 0.99789
# epoch: 42, passed number of graphs: 672, train running loss: 0.00019 (passed time: 1h 34m 23s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00012, rec: 0.99988, prc: 0.99282, f1: 0.99634, f1_macro: 0.99813
# epoch: 42, passed number of graphs: 768, train running loss: 0.00019 (passed time: 1h 34m 37s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00012, rec: 0.99988, prc: 0.99665, f1: 0.99826, f1_macro: 0.99911
# Validation --- epoch: 42, loss: 0.00230
#           prc: 0.99221, fnr: 0.00441, f1_macro: 0.99657, acc: 0.99973, f1: 0.99329, fpr: 0.00018, rec: 0.99559
# epoch: 43, passed number of graphs: 96, train running loss: 0.00015 (passed time: 1h 35m 14s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99675, f1: 0.99833, f1_macro: 0.99915
# epoch: 43, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 35m 28s)
#           acc: 0.99960, fpr: 0.00040, fnr: 0.00016, rec: 0.99984, prc: 0.98204, f1: 0.99086, f1_macro: 0.99533
# epoch: 43, passed number of graphs: 288, train running loss: 0.00020 (passed time: 1h 35m 43s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00008, rec: 0.99992, prc: 0.98635, f1: 0.99309, f1_macro: 0.99647
# epoch: 43, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 35m 57s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99035, f1: 0.99515, f1_macro: 0.99752
# epoch: 43, passed number of graphs: 480, train running loss: 0.00019 (passed time: 1h 36m 11s)
#           acc: 0.99920, fpr: 0.00081, fnr: 0.00024, rec: 0.99976, prc: 0.96461, f1: 0.98187, f1_macro: 0.99073
# epoch: 43, passed number of graphs: 576, train running loss: 0.00018 (passed time: 1h 36m 25s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00004, rec: 0.99996, prc: 0.99183, f1: 0.99588, f1_macro: 0.99789
# epoch: 43, passed number of graphs: 672, train running loss: 0.00019 (passed time: 1h 36m 39s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00012, rec: 0.99988, prc: 0.99282, f1: 0.99634, f1_macro: 0.99813
# epoch: 43, passed number of graphs: 768, train running loss: 0.00019 (passed time: 1h 36m 53s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00012, rec: 0.99988, prc: 0.99665, f1: 0.99826, f1_macro: 0.99911
# Validation --- epoch: 43, loss: 0.00230
#           prc: 0.99221, fnr: 0.00441, f1_macro: 0.99657, acc: 0.99973, f1: 0.99329, fpr: 0.00018, rec: 0.99559
# epoch: 44, passed number of graphs: 96, train running loss: 0.00015 (passed time: 1h 37m 30s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99675, f1: 0.99833, f1_macro: 0.99915
# epoch: 44, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 37m 44s)
#           acc: 0.99960, fpr: 0.00040, fnr: 0.00016, rec: 0.99984, prc: 0.98204, f1: 0.99086, f1_macro: 0.99533
# epoch: 44, passed number of graphs: 288, train running loss: 0.00020 (passed time: 1h 37m 58s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00008, rec: 0.99992, prc: 0.98635, f1: 0.99309, f1_macro: 0.99647
# epoch: 44, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 38m 13s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99035, f1: 0.99515, f1_macro: 0.99752
# epoch: 44, passed number of graphs: 480, train running loss: 0.00019 (passed time: 1h 38m 27s)
#           acc: 0.99920, fpr: 0.00081, fnr: 0.00024, rec: 0.99976, prc: 0.96465, f1: 0.98189, f1_macro: 0.99074
# epoch: 44, passed number of graphs: 576, train running loss: 0.00018 (passed time: 1h 38m 41s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00004, rec: 0.99996, prc: 0.99183, f1: 0.99588, f1_macro: 0.99789
# epoch: 44, passed number of graphs: 672, train running loss: 0.00019 (passed time: 1h 38m 55s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00012, rec: 0.99988, prc: 0.99282, f1: 0.99634, f1_macro: 0.99813
# epoch: 44, passed number of graphs: 768, train running loss: 0.00019 (passed time: 1h 39m 9s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00012, rec: 0.99988, prc: 0.99665, f1: 0.99826, f1_macro: 0.99911
# Validation --- epoch: 44, loss: 0.00230
#           prc: 0.99221, fnr: 0.00441, f1_macro: 0.99657, acc: 0.99973, f1: 0.99329, fpr: 0.00018, rec: 0.99559
# epoch: 45, passed number of graphs: 96, train running loss: 0.00015 (passed time: 1h 39m 45s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99675, f1: 0.99833, f1_macro: 0.99915
# epoch: 45, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 39m 59s)
#           acc: 0.99960, fpr: 0.00040, fnr: 0.00016, rec: 0.99984, prc: 0.98204, f1: 0.99086, f1_macro: 0.99533
# epoch: 45, passed number of graphs: 288, train running loss: 0.00020 (passed time: 1h 40m 14s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00008, rec: 0.99992, prc: 0.98635, f1: 0.99309, f1_macro: 0.99647
# epoch: 45, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 40m 28s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99035, f1: 0.99515, f1_macro: 0.99752
# epoch: 45, passed number of graphs: 480, train running loss: 0.00019 (passed time: 1h 40m 42s)
#           acc: 0.99920, fpr: 0.00081, fnr: 0.00024, rec: 0.99976, prc: 0.96465, f1: 0.98189, f1_macro: 0.99074
# epoch: 45, passed number of graphs: 576, train running loss: 0.00018 (passed time: 1h 40m 56s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00004, rec: 0.99996, prc: 0.99183, f1: 0.99588, f1_macro: 0.99789
# epoch: 45, passed number of graphs: 672, train running loss: 0.00019 (passed time: 1h 41m 10s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00012, rec: 0.99988, prc: 0.99282, f1: 0.99634, f1_macro: 0.99813
# epoch: 45, passed number of graphs: 768, train running loss: 0.00019 (passed time: 1h 41m 24s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00012, rec: 0.99988, prc: 0.99665, f1: 0.99826, f1_macro: 0.99911
# Validation --- epoch: 45, loss: 0.00230
#           prc: 0.99221, fnr: 0.00441, f1_macro: 0.99657, acc: 0.99973, f1: 0.99329, fpr: 0.00018, rec: 0.99559
# epoch: 46, passed number of graphs: 96, train running loss: 0.00015 (passed time: 1h 42m 0s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99675, f1: 0.99833, f1_macro: 0.99915
# epoch: 46, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 42m 14s)
#           acc: 0.99960, fpr: 0.00040, fnr: 0.00016, rec: 0.99984, prc: 0.98204, f1: 0.99086, f1_macro: 0.99533
# epoch: 46, passed number of graphs: 288, train running loss: 0.00020 (passed time: 1h 42m 28s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00008, rec: 0.99992, prc: 0.98635, f1: 0.99309, f1_macro: 0.99647
# epoch: 46, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 42m 43s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99035, f1: 0.99515, f1_macro: 0.99752
# epoch: 46, passed number of graphs: 480, train running loss: 0.00019 (passed time: 1h 42m 57s)
#           acc: 0.99920, fpr: 0.00081, fnr: 0.00024, rec: 0.99976, prc: 0.96465, f1: 0.98189, f1_macro: 0.99074
# epoch: 46, passed number of graphs: 576, train running loss: 0.00018 (passed time: 1h 43m 11s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00004, rec: 0.99996, prc: 0.99183, f1: 0.99588, f1_macro: 0.99789
# epoch: 46, passed number of graphs: 672, train running loss: 0.00019 (passed time: 1h 43m 25s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00012, rec: 0.99988, prc: 0.99282, f1: 0.99634, f1_macro: 0.99813
# epoch: 46, passed number of graphs: 768, train running loss: 0.00019 (passed time: 1h 43m 39s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00012, rec: 0.99988, prc: 0.99665, f1: 0.99826, f1_macro: 0.99911
# Validation --- epoch: 46, loss: 0.00230
#           prc: 0.99221, fnr: 0.00441, f1_macro: 0.99657, acc: 0.99973, f1: 0.99329, fpr: 0.00018, rec: 0.99559
# epoch: 47, passed number of graphs: 96, train running loss: 0.00015 (passed time: 1h 44m 15s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99675, f1: 0.99833, f1_macro: 0.99915
# epoch: 47, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 44m 29s)
#           acc: 0.99960, fpr: 0.00040, fnr: 0.00016, rec: 0.99984, prc: 0.98204, f1: 0.99086, f1_macro: 0.99533
# epoch: 47, passed number of graphs: 288, train running loss: 0.00020 (passed time: 1h 44m 44s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00008, rec: 0.99992, prc: 0.98635, f1: 0.99309, f1_macro: 0.99647
# epoch: 47, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 44m 58s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99035, f1: 0.99515, f1_macro: 0.99752
# epoch: 47, passed number of graphs: 480, train running loss: 0.00019 (passed time: 1h 45m 12s)
#           acc: 0.99920, fpr: 0.00081, fnr: 0.00024, rec: 0.99976, prc: 0.96465, f1: 0.98189, f1_macro: 0.99074
# epoch: 47, passed number of graphs: 576, train running loss: 0.00018 (passed time: 1h 45m 26s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00004, rec: 0.99996, prc: 0.99183, f1: 0.99588, f1_macro: 0.99789
# epoch: 47, passed number of graphs: 672, train running loss: 0.00019 (passed time: 1h 45m 40s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00012, rec: 0.99988, prc: 0.99282, f1: 0.99634, f1_macro: 0.99813
# epoch: 47, passed number of graphs: 768, train running loss: 0.00019 (passed time: 1h 45m 54s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00012, rec: 0.99988, prc: 0.99665, f1: 0.99826, f1_macro: 0.99911
# Validation --- epoch: 47, loss: 0.00230
#           prc: 0.99221, fnr: 0.00441, f1_macro: 0.99657, acc: 0.99973, f1: 0.99329, fpr: 0.00018, rec: 0.99559
# epoch: 48, passed number of graphs: 96, train running loss: 0.00015 (passed time: 1h 46m 30s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99675, f1: 0.99833, f1_macro: 0.99915
# epoch: 48, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 46m 45s)
#           acc: 0.99960, fpr: 0.00040, fnr: 0.00016, rec: 0.99984, prc: 0.98204, f1: 0.99086, f1_macro: 0.99533
# epoch: 48, passed number of graphs: 288, train running loss: 0.00020 (passed time: 1h 46m 59s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00008, rec: 0.99992, prc: 0.98635, f1: 0.99309, f1_macro: 0.99647
# epoch: 48, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 47m 13s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99035, f1: 0.99515, f1_macro: 0.99752
# epoch: 48, passed number of graphs: 480, train running loss: 0.00019 (passed time: 1h 47m 27s)
#           acc: 0.99920, fpr: 0.00081, fnr: 0.00024, rec: 0.99976, prc: 0.96461, f1: 0.98187, f1_macro: 0.99073
# epoch: 48, passed number of graphs: 576, train running loss: 0.00018 (passed time: 1h 47m 41s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00004, rec: 0.99996, prc: 0.99183, f1: 0.99588, f1_macro: 0.99789
# epoch: 48, passed number of graphs: 672, train running loss: 0.00019 (passed time: 1h 47m 55s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00012, rec: 0.99988, prc: 0.99282, f1: 0.99634, f1_macro: 0.99813
# epoch: 48, passed number of graphs: 768, train running loss: 0.00019 (passed time: 1h 48m 9s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00012, rec: 0.99988, prc: 0.99665, f1: 0.99826, f1_macro: 0.99911
# Validation --- epoch: 48, loss: 0.00230
#           prc: 0.99221, fnr: 0.00441, f1_macro: 0.99657, acc: 0.99973, f1: 0.99329, fpr: 0.00018, rec: 0.99559
# epoch: 49, passed number of graphs: 96, train running loss: 0.00015 (passed time: 1h 48m 46s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99675, f1: 0.99833, f1_macro: 0.99915
# epoch: 49, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 49m 1s)
#           acc: 0.99960, fpr: 0.00040, fnr: 0.00016, rec: 0.99984, prc: 0.98204, f1: 0.99086, f1_macro: 0.99533
# epoch: 49, passed number of graphs: 288, train running loss: 0.00020 (passed time: 1h 49m 15s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00008, rec: 0.99992, prc: 0.98635, f1: 0.99309, f1_macro: 0.99647
# epoch: 49, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 49m 29s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99035, f1: 0.99515, f1_macro: 0.99752
# epoch: 49, passed number of graphs: 480, train running loss: 0.00019 (passed time: 1h 49m 43s)
#           acc: 0.99920, fpr: 0.00081, fnr: 0.00024, rec: 0.99976, prc: 0.96461, f1: 0.98187, f1_macro: 0.99073
# epoch: 49, passed number of graphs: 576, train running loss: 0.00018 (passed time: 1h 49m 57s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00004, rec: 0.99996, prc: 0.99183, f1: 0.99588, f1_macro: 0.99789
# epoch: 49, passed number of graphs: 672, train running loss: 0.00019 (passed time: 1h 50m 11s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00012, rec: 0.99988, prc: 0.99282, f1: 0.99634, f1_macro: 0.99813
# epoch: 49, passed number of graphs: 768, train running loss: 0.00019 (passed time: 1h 50m 25s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00012, rec: 0.99988, prc: 0.99665, f1: 0.99826, f1_macro: 0.99911
# Validation --- epoch: 49, loss: 0.00230
#           prc: 0.99221, fnr: 0.00441, f1_macro: 0.99657, acc: 0.99973, f1: 0.99329, fpr: 0.00018, rec: 0.99559
# epoch: 50, passed number of graphs: 96, train running loss: 0.00015 (passed time: 1h 51m 2s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99675, f1: 0.99833, f1_macro: 0.99915
# epoch: 50, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 51m 16s)
#           acc: 0.99960, fpr: 0.00040, fnr: 0.00016, rec: 0.99984, prc: 0.98204, f1: 0.99086, f1_macro: 0.99533
# epoch: 50, passed number of graphs: 288, train running loss: 0.00020 (passed time: 1h 51m 31s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00008, rec: 0.99992, prc: 0.98635, f1: 0.99309, f1_macro: 0.99647
# epoch: 50, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 51m 45s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99035, f1: 0.99515, f1_macro: 0.99752
# epoch: 50, passed number of graphs: 480, train running loss: 0.00019 (passed time: 1h 51m 59s)
#           acc: 0.99920, fpr: 0.00081, fnr: 0.00024, rec: 0.99976, prc: 0.96461, f1: 0.98187, f1_macro: 0.99073
# epoch: 50, passed number of graphs: 576, train running loss: 0.00018 (passed time: 1h 52m 13s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00004, rec: 0.99996, prc: 0.99183, f1: 0.99588, f1_macro: 0.99789
# epoch: 50, passed number of graphs: 672, train running loss: 0.00019 (passed time: 1h 52m 27s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00012, rec: 0.99988, prc: 0.99282, f1: 0.99634, f1_macro: 0.99813
# epoch: 50, passed number of graphs: 768, train running loss: 0.00019 (passed time: 1h 52m 41s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00012, rec: 0.99988, prc: 0.99665, f1: 0.99826, f1_macro: 0.99911
# Validation --- epoch: 50, loss: 0.00230
#           prc: 0.99221, fnr: 0.00441, f1_macro: 0.99657, acc: 0.99973, f1: 0.99329, fpr: 0.00018, rec: 0.99559
# ************ best model obtained after epoch 33, saved at ./saved_models/GIN_32: 0.9933153722043536.pt ************
# Testing --- loss: 0.00198
#           prc: 0.98972, fnr: 0.00291, f1_macro: 0.99644, acc: 0.99970, f1: 0.99303, fpr: 0.00024, rec: 0.99709
